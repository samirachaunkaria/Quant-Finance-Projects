# %%
# Import libraries
import os
import json
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Function to extract text content from .ipynb files
def extract_text_from_ipynb(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        content = json.load(f)
    text_data = []
    for cell in content.get('cells', []):
        if cell.get('cell_type') == 'markdown' or cell.get('cell_type') == 'code':
            text_data.append(' '.join(cell.get('source', [])))
    return ' '.join(text_data)

# Function to calculate pairwise similarity
def calculate_similarity(file_texts, file_names):
    # Vectorize text using TF-IDF
    vectorizer = TfidfVectorizer(stop_words='english')
    tfidf_matrix = vectorizer.fit_transform(file_texts)
    
    # Compute cosine similarity
    similarity_matrix = cosine_similarity(tfidf_matrix)
    
    # Create a DataFrame for readability
    similarity_df = pd.DataFrame(similarity_matrix, index=file_names, columns=file_names)
    return similarity_df

# Main function
def analyze_similarity_in_folder(folder_path):
    # Gather .ipynb files in the folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.ipynb')]
    file_texts = []
    for file in files:
        file_path = os.path.join(folder_path, file)
        file_texts.append(extract_text_from_ipynb(file_path))
    
    # Calculate similarity matrix
    similarity_df = calculate_similarity(file_texts, files)
    
    # Identify high similarity pairs
    high_similarity_pairs = []
    for i in range(len(files)):
        for j in range(i + 1, len(files)):
            if similarity_df.iloc[i, j] > 0.8:  # Threshold for high similarity
                high_similarity_pairs.append((files[i], files[j], similarity_df.iloc[i, j]))
    
    return similarity_df, high_similarity_pairs

# Specify the folder path
folder_path = "/Users/samirachaunkaria/Desktop/FIN 359 Coursework"

# Run the analysis
similarity_matrix, high_similarity_pairs = analyze_similarity_in_folder(folder_path)

# Output results
print("Similarity Matrix:")
print(similarity_matrix)

if high_similarity_pairs:
    print("\nHighly Similar File Pairs (Threshold > 0.8):")
    for pair in high_similarity_pairs:
        print(f"{pair[0]} and {pair[1]}: Similarity = {pair[2]:.2f}")
else:
    print("\nNo highly similar file pairs found.")
# Out:
# Similarity Matrix:
#                                                     Untitled7.ipynb  \
# Untitled7.ipynb                                                 0.0
# if-else statement.ipynb                                         0.0
# Launcher.ipynb                                                  0.0
# Untitled5.ipynb                                                 0.0
# Untitled1.ipynb                                                 0.0
# Intro to Pandas - In class demo (Oct 29).ipynb                  0.0
# Untitled3.ipynb                                                 0.0
# Untitled.ipynb                                                  0.0
# samira_chaunkaria_homework_3.ipynb                              0.0
# Untitled4.ipynb                                                 0.0
# Untitled6.ipynb                                                 0.0
# Robotic_OLS.ipynb                                               0.0
# NPV exercise.ipynb                                              0.0
# Pandas Problem Set - Solutions.ipynb                            0.0
# Capital Budgeting - Python examples (Questions)...              0.0
# Untitled2.ipynb                                                 0.0
# What are variables?.ipynb                                       0.0
# Practice Problem Set - Functions and IF stateme...              0.0
# Samira_Chaunkaria_extracredit.ipynb                             0.0
# Pandas Problem Set - Questions.ipynb                            0.0
# In class exercise 10-28.ipynb                                   0.0
# Untitled8.ipynb                                                 0.0
# If statements.ipynb                                             0.0
# HW3_Instruction-1.ipynb                                         0.0
# Exercise_Functions (Questions).ipynb                            0.0
# Extra Credit - Exercise of NUMPY (Duration Anal...              0.0
# Exercise_Functions (Solutions).ipynb                            0.0
# Pandas_DataFrame.ipynb                                          0.0
# Untitled9.ipynb                                                 0.0
# How to identify working directory.ipynb                         0.0
# Pandas Package.ipynb                                            0.0
#
#                                                     if-else statement.ipynb  \
# Untitled7.ipynb                                                    0.000000
# if-else statement.ipynb                                            1.000000
# Launcher.ipynb                                                     0.110761
# Untitled5.ipynb                                                    0.000000
# Untitled1.ipynb                                                    0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                     0.004672
# Untitled3.ipynb                                                    0.000000
# Untitled.ipynb                                                     0.000000
# samira_chaunkaria_homework_3.ipynb                                 0.077985
# Untitled4.ipynb                                                    0.000000
# Untitled6.ipynb                                                    0.096044
# Robotic_OLS.ipynb                                                  0.038426
# NPV exercise.ipynb                                                 0.082394
# Pandas Problem Set - Solutions.ipynb                               0.043607
# Capital Budgeting - Python examples (Questions)...                 0.093382
# Untitled2.ipynb                                                    0.077985
# What are variables?.ipynb                                          0.179413
# Practice Problem Set - Functions and IF stateme...                 0.024382
# Samira_Chaunkaria_extracredit.ipynb                                0.104560
# Pandas Problem Set - Questions.ipynb                               0.027341
# In class exercise 10-28.ipynb                                      0.000000
# Untitled8.ipynb                                                    0.000000
# If statements.ipynb                                                0.675975
# HW3_Instruction-1.ipynb                                            0.017939
# Exercise_Functions (Questions).ipynb                               0.109553
# Extra Credit - Exercise of NUMPY (Duration Anal...                 0.010731
# Exercise_Functions (Solutions).ipynb                               0.111685
# Pandas_DataFrame.ipynb                                             0.008352
# Untitled9.ipynb                                                    0.000000
# How to identify working directory.ipynb                            0.050610
# Pandas Package.ipynb                                               0.003414
#
#                                                     Launcher.ipynb  \
# Untitled7.ipynb                                           0.000000
# if-else statement.ipynb                                   0.110761
# Launcher.ipynb                                            1.000000
# Untitled5.ipynb                                           0.000000
# Untitled1.ipynb                                           0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb            0.012278
# Untitled3.ipynb                                           0.029976
# Untitled.ipynb                                            0.000000
# samira_chaunkaria_homework_3.ipynb                        0.048033
# Untitled4.ipynb                                           0.000000
# Untitled6.ipynb                                           0.022393
# Robotic_OLS.ipynb                                         0.021139
# NPV exercise.ipynb                                        0.009776
# Pandas Problem Set - Solutions.ipynb                      0.013221
# Capital Budgeting - Python examples (Questions)...        0.013824
# Untitled2.ipynb                                           0.048033
# What are variables?.ipynb                                 0.034444
# Practice Problem Set - Functions and IF stateme...        0.002172
# Samira_Chaunkaria_extracredit.ipynb                       0.025431
# Pandas Problem Set - Questions.ipynb                      0.001716
# In class exercise 10-28.ipynb                             0.024272
# Untitled8.ipynb                                           0.000000
# If statements.ipynb                                       0.073628
# HW3_Instruction-1.ipynb                                   0.091465
# Exercise_Functions (Questions).ipynb                      0.008253
# Extra Credit - Exercise of NUMPY (Duration Anal...        0.012153
# Exercise_Functions (Solutions).ipynb                      0.012971
# Pandas_DataFrame.ipynb                                    0.019334
# Untitled9.ipynb                                           0.058079
# How to identify working directory.ipynb                   0.409998
# Pandas Package.ipynb                                      0.020472
#
#                                                     Untitled5.ipynb  \
# Untitled7.ipynb                                                 0.0
# if-else statement.ipynb                                         0.0
# Launcher.ipynb                                                  0.0
# Untitled5.ipynb                                                 0.0
# Untitled1.ipynb                                                 0.0
# Intro to Pandas - In class demo (Oct 29).ipynb                  0.0
# Untitled3.ipynb                                                 0.0
# Untitled.ipynb                                                  0.0
# samira_chaunkaria_homework_3.ipynb                              0.0
# Untitled4.ipynb                                                 0.0
# Untitled6.ipynb                                                 0.0
# Robotic_OLS.ipynb                                               0.0
# NPV exercise.ipynb                                              0.0
# Pandas Problem Set - Solutions.ipynb                            0.0
# Capital Budgeting - Python examples (Questions)...              0.0
# Untitled2.ipynb                                                 0.0
# What are variables?.ipynb                                       0.0
# Practice Problem Set - Functions and IF stateme...              0.0
# Samira_Chaunkaria_extracredit.ipynb                             0.0
# Pandas Problem Set - Questions.ipynb                            0.0
# In class exercise 10-28.ipynb                                   0.0
# Untitled8.ipynb                                                 0.0
# If statements.ipynb                                             0.0
# HW3_Instruction-1.ipynb                                         0.0
# Exercise_Functions (Questions).ipynb                            0.0
# Extra Credit - Exercise of NUMPY (Duration Anal...              0.0
# Exercise_Functions (Solutions).ipynb                            0.0
# Pandas_DataFrame.ipynb                                          0.0
# Untitled9.ipynb                                                 0.0
# How to identify working directory.ipynb                         0.0
# Pandas Package.ipynb                                            0.0
#
#                                                     Untitled1.ipynb  \
# Untitled7.ipynb                                                 0.0
# if-else statement.ipynb                                         0.0
# Launcher.ipynb                                                  0.0
# Untitled5.ipynb                                                 0.0
# Untitled1.ipynb                                                 0.0
# Intro to Pandas - In class demo (Oct 29).ipynb                  0.0
# Untitled3.ipynb                                                 0.0
# Untitled.ipynb                                                  0.0
# samira_chaunkaria_homework_3.ipynb                              0.0
# Untitled4.ipynb                                                 0.0
# Untitled6.ipynb                                                 0.0
# Robotic_OLS.ipynb                                               0.0
# NPV exercise.ipynb                                              0.0
# Pandas Problem Set - Solutions.ipynb                            0.0
# Capital Budgeting - Python examples (Questions)...              0.0
# Untitled2.ipynb                                                 0.0
# What are variables?.ipynb                                       0.0
# Practice Problem Set - Functions and IF stateme...              0.0
# Samira_Chaunkaria_extracredit.ipynb                             0.0
# Pandas Problem Set - Questions.ipynb                            0.0
# In class exercise 10-28.ipynb                                   0.0
# Untitled8.ipynb                                                 0.0
# If statements.ipynb                                             0.0
# HW3_Instruction-1.ipynb                                         0.0
# Exercise_Functions (Questions).ipynb                            0.0
# Extra Credit - Exercise of NUMPY (Duration Anal...              0.0
# Exercise_Functions (Solutions).ipynb                            0.0
# Pandas_DataFrame.ipynb                                          0.0
# Untitled9.ipynb                                                 0.0
# How to identify working directory.ipynb                         0.0
# Pandas Package.ipynb                                            0.0
#
#                                                     Intro to Pandas - In class demo (Oct 29).ipynb  \
# Untitled7.ipynb                                                                           0.000000
# if-else statement.ipynb                                                                   0.004672
# Launcher.ipynb                                                                            0.012278
# Untitled5.ipynb                                                                           0.000000
# Untitled1.ipynb                                                                           0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                                            1.000000
# Untitled3.ipynb                                                                           0.258647
# Untitled.ipynb                                                                            0.000000
# samira_chaunkaria_homework_3.ipynb                                                        0.048188
# Untitled4.ipynb                                                                           0.000000
# Untitled6.ipynb                                                                           0.017639
# Robotic_OLS.ipynb                                                                         0.031026
# NPV exercise.ipynb                                                                        0.001532
# Pandas Problem Set - Solutions.ipynb                                                      0.057913
# Capital Budgeting - Python examples (Questions)...                                        0.020789
# Untitled2.ipynb                                                                           0.048188
# What are variables?.ipynb                                                                 0.012848
# Practice Problem Set - Functions and IF stateme...                                        0.000000
# Samira_Chaunkaria_extracredit.ipynb                                                       0.016877
# Pandas Problem Set - Questions.ipynb                                                      0.056521
# In class exercise 10-28.ipynb                                                             0.062425
# Untitled8.ipynb                                                                           0.000000
# If statements.ipynb                                                                       0.009396
# HW3_Instruction-1.ipynb                                                                   0.075270
# Exercise_Functions (Questions).ipynb                                                      0.002216
# Extra Credit - Exercise of NUMPY (Duration Anal...                                        0.013265
# Exercise_Functions (Solutions).ipynb                                                      0.002322
# Pandas_DataFrame.ipynb                                                                    0.367474
# Untitled9.ipynb                                                                           0.037656
# How to identify working directory.ipynb                                                   0.005610
# Pandas Package.ipynb                                                                      0.036846
#
#                                                     Untitled3.ipynb  \
# Untitled7.ipynb                                            0.000000
# if-else statement.ipynb                                    0.000000
# Launcher.ipynb                                             0.029976
# Untitled5.ipynb                                            0.000000
# Untitled1.ipynb                                            0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb             0.258647
# Untitled3.ipynb                                            1.000000
# Untitled.ipynb                                             0.000000
# samira_chaunkaria_homework_3.ipynb                         0.077961
# Untitled4.ipynb                                            0.000000
# Untitled6.ipynb                                            0.006619
# Robotic_OLS.ipynb                                          0.088488
# NPV exercise.ipynb                                         0.009096
# Pandas Problem Set - Solutions.ipynb                       0.418230
# Capital Budgeting - Python examples (Questions)...         0.026708
# Untitled2.ipynb                                            0.077961
# What are variables?.ipynb                                  0.000000
# Practice Problem Set - Functions and IF stateme...         0.006163
# Samira_Chaunkaria_extracredit.ipynb                        0.009465
# Pandas Problem Set - Questions.ipynb                       0.331871
# In class exercise 10-28.ipynb                              0.235763
# Untitled8.ipynb                                            0.000000
# If statements.ipynb                                        0.000000
# HW3_Instruction-1.ipynb                                    0.222541
# Exercise_Functions (Questions).ipynb                       0.033658
# Extra Credit - Exercise of NUMPY (Duration Anal...         0.005846
# Exercise_Functions (Solutions).ipynb                       0.012269
# Pandas_DataFrame.ipynb                                     0.247210
# Untitled9.ipynb                                            0.073675
# How to identify working directory.ipynb                    0.013697
# Pandas Package.ipynb                                       0.281073
#
#                                                     Untitled.ipynb  \
# Untitled7.ipynb                                                0.0
# if-else statement.ipynb                                        0.0
# Launcher.ipynb                                                 0.0
# Untitled5.ipynb                                                0.0
# Untitled1.ipynb                                                0.0
# Intro to Pandas - In class demo (Oct 29).ipynb                 0.0
# Untitled3.ipynb                                                0.0
# Untitled.ipynb                                                 0.0
# samira_chaunkaria_homework_3.ipynb                             0.0
# Untitled4.ipynb                                                0.0
# Untitled6.ipynb                                                0.0
# Robotic_OLS.ipynb                                              0.0
# NPV exercise.ipynb                                             0.0
# Pandas Problem Set - Solutions.ipynb                           0.0
# Capital Budgeting - Python examples (Questions)...             0.0
# Untitled2.ipynb                                                0.0
# What are variables?.ipynb                                      0.0
# Practice Problem Set - Functions and IF stateme...             0.0
# Samira_Chaunkaria_extracredit.ipynb                            0.0
# Pandas Problem Set - Questions.ipynb                           0.0
# In class exercise 10-28.ipynb                                  0.0
# Untitled8.ipynb                                                0.0
# If statements.ipynb                                            0.0
# HW3_Instruction-1.ipynb                                        0.0
# Exercise_Functions (Questions).ipynb                           0.0
# Extra Credit - Exercise of NUMPY (Duration Anal...             0.0
# Exercise_Functions (Solutions).ipynb                           0.0
# Pandas_DataFrame.ipynb                                         0.0
# Untitled9.ipynb                                                0.0
# How to identify working directory.ipynb                        0.0
# Pandas Package.ipynb                                           0.0
#
#                                                     samira_chaunkaria_homework_3.ipynb  \
# Untitled7.ipynb                                                               0.000000
# if-else statement.ipynb                                                       0.077985
# Launcher.ipynb                                                                0.048033
# Untitled5.ipynb                                                               0.000000
# Untitled1.ipynb                                                               0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                                0.048188
# Untitled3.ipynb                                                               0.077961
# Untitled.ipynb                                                                0.000000
# samira_chaunkaria_homework_3.ipynb                                            1.000000
# Untitled4.ipynb                                                               0.000000
# Untitled6.ipynb                                                               0.057787
# Robotic_OLS.ipynb                                                             0.152620
# NPV exercise.ipynb                                                            0.045742
# Pandas Problem Set - Solutions.ipynb                                          0.140173
# Capital Budgeting - Python examples (Questions)...                            0.038991
# Untitled2.ipynb                                                               1.000000
# What are variables?.ipynb                                                     0.031314
# Practice Problem Set - Functions and IF stateme...                            0.014712
# Samira_Chaunkaria_extracredit.ipynb                                           0.118420
# Pandas Problem Set - Questions.ipynb                                          0.106985
# In class exercise 10-28.ipynb                                                 0.190944
# Untitled8.ipynb                                                               0.000000
# If statements.ipynb                                                           0.073852
# HW3_Instruction-1.ipynb                                                       0.576177
# Exercise_Functions (Questions).ipynb                                          0.020586
# Extra Credit - Exercise of NUMPY (Duration Anal...                            0.047286
# Exercise_Functions (Solutions).ipynb                                          0.020745
# Pandas_DataFrame.ipynb                                                        0.112724
# Untitled9.ipynb                                                               0.035789
# How to identify working directory.ipynb                                       0.031890
# Pandas Package.ipynb                                                          0.089586
#
#                                                     Untitled4.ipynb  ...  \
# Untitled7.ipynb                                                 0.0  ...
# if-else statement.ipynb                                         0.0  ...
# Launcher.ipynb                                                  0.0  ...
# Untitled5.ipynb                                                 0.0  ...
# Untitled1.ipynb                                                 0.0  ...
# Intro to Pandas - In class demo (Oct 29).ipynb                  0.0  ...
# Untitled3.ipynb                                                 0.0  ...
# Untitled.ipynb                                                  0.0  ...
# samira_chaunkaria_homework_3.ipynb                              0.0  ...
# Untitled4.ipynb                                                 0.0  ...
# Untitled6.ipynb                                                 0.0  ...
# Robotic_OLS.ipynb                                               0.0  ...
# NPV exercise.ipynb                                              0.0  ...
# Pandas Problem Set - Solutions.ipynb                            0.0  ...
# Capital Budgeting - Python examples (Questions)...              0.0  ...
# Untitled2.ipynb                                                 0.0  ...
# What are variables?.ipynb                                       0.0  ...
# Practice Problem Set - Functions and IF stateme...              0.0  ...
# Samira_Chaunkaria_extracredit.ipynb                             0.0  ...
# Pandas Problem Set - Questions.ipynb                            0.0  ...
# In class exercise 10-28.ipynb                                   0.0  ...
# Untitled8.ipynb                                                 0.0  ...
# If statements.ipynb                                             0.0  ...
# HW3_Instruction-1.ipynb                                         0.0  ...
# Exercise_Functions (Questions).ipynb                            0.0  ...
# Extra Credit - Exercise of NUMPY (Duration Anal...              0.0  ...
# Exercise_Functions (Solutions).ipynb                            0.0  ...
# Pandas_DataFrame.ipynb                                          0.0  ...
# Untitled9.ipynb                                                 0.0  ...
# How to identify working directory.ipynb                         0.0  ...
# Pandas Package.ipynb                                            0.0  ...
#
#                                                     Untitled8.ipynb  \
# Untitled7.ipynb                                                 0.0
# if-else statement.ipynb                                         0.0
# Launcher.ipynb                                                  0.0
# Untitled5.ipynb                                                 0.0
# Untitled1.ipynb                                                 0.0
# Intro to Pandas - In class demo (Oct 29).ipynb                  0.0
# Untitled3.ipynb                                                 0.0
# Untitled.ipynb                                                  0.0
# samira_chaunkaria_homework_3.ipynb                              0.0
# Untitled4.ipynb                                                 0.0
# Untitled6.ipynb                                                 0.0
# Robotic_OLS.ipynb                                               0.0
# NPV exercise.ipynb                                              0.0
# Pandas Problem Set - Solutions.ipynb                            0.0
# Capital Budgeting - Python examples (Questions)...              0.0
# Untitled2.ipynb                                                 0.0
# What are variables?.ipynb                                       0.0
# Practice Problem Set - Functions and IF stateme...              0.0
# Samira_Chaunkaria_extracredit.ipynb                             0.0
# Pandas Problem Set - Questions.ipynb                            0.0
# In class exercise 10-28.ipynb                                   0.0
# Untitled8.ipynb                                                 0.0
# If statements.ipynb                                             0.0
# HW3_Instruction-1.ipynb                                         0.0
# Exercise_Functions (Questions).ipynb                            0.0
# Extra Credit - Exercise of NUMPY (Duration Anal...              0.0
# Exercise_Functions (Solutions).ipynb                            0.0
# Pandas_DataFrame.ipynb                                          0.0
# Untitled9.ipynb                                                 0.0
# How to identify working directory.ipynb                         0.0
# Pandas Package.ipynb                                            0.0
#
#                                                     If statements.ipynb  \
# Untitled7.ipynb                                                0.000000
# if-else statement.ipynb                                        0.675975
# Launcher.ipynb                                                 0.073628
# Untitled5.ipynb                                                0.000000
# Untitled1.ipynb                                                0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                 0.009396
# Untitled3.ipynb                                                0.000000
# Untitled.ipynb                                                 0.000000
# samira_chaunkaria_homework_3.ipynb                             0.073852
# Untitled4.ipynb                                                0.000000
# Untitled6.ipynb                                                0.084187
# Robotic_OLS.ipynb                                              0.035827
# NPV exercise.ipynb                                             0.068116
# Pandas Problem Set - Solutions.ipynb                           0.041306
# Capital Budgeting - Python examples (Questions)...             0.083893
# Untitled2.ipynb                                                0.073852
# What are variables?.ipynb                                      0.157498
# Practice Problem Set - Functions and IF stateme...             0.025684
# Samira_Chaunkaria_extracredit.ipynb                            0.088217
# Pandas Problem Set - Questions.ipynb                           0.026834
# In class exercise 10-28.ipynb                                  0.000000
# Untitled8.ipynb                                                0.000000
# If statements.ipynb                                            1.000000
# HW3_Instruction-1.ipynb                                        0.025088
# Exercise_Functions (Questions).ipynb                           0.094086
# Extra Credit - Exercise of NUMPY (Duration Anal...             0.010932
# Exercise_Functions (Solutions).ipynb                           0.089043
# Pandas_DataFrame.ipynb                                         0.008724
# Untitled9.ipynb                                                0.012699
# How to identify working directory.ipynb                        0.045756
# Pandas Package.ipynb                                           0.004562
#
#                                                     HW3_Instruction-1.ipynb  \
# Untitled7.ipynb                                                    0.000000
# if-else statement.ipynb                                            0.017939
# Launcher.ipynb                                                     0.091465
# Untitled5.ipynb                                                    0.000000
# Untitled1.ipynb                                                    0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                     0.075270
# Untitled3.ipynb                                                    0.222541
# Untitled.ipynb                                                     0.000000
# samira_chaunkaria_homework_3.ipynb                                 0.576177
# Untitled4.ipynb                                                    0.000000
# Untitled6.ipynb                                                    0.069105
# Robotic_OLS.ipynb                                                  0.140090
# NPV exercise.ipynb                                                 0.054254
# Pandas Problem Set - Solutions.ipynb                               0.249451
# Capital Budgeting - Python examples (Questions)...                 0.055730
# Untitled2.ipynb                                                    0.576177
# What are variables?.ipynb                                          0.012559
# Practice Problem Set - Functions and IF stateme...                 0.021347
# Samira_Chaunkaria_extracredit.ipynb                                0.088815
# Pandas Problem Set - Questions.ipynb                               0.247776
# In class exercise 10-28.ipynb                                      0.274462
# Untitled8.ipynb                                                    0.000000
# If statements.ipynb                                                0.025088
# HW3_Instruction-1.ipynb                                            1.000000
# Exercise_Functions (Questions).ipynb                               0.031276
# Extra Credit - Exercise of NUMPY (Duration Anal...                 0.135718
# Exercise_Functions (Solutions).ipynb                               0.019387
# Pandas_DataFrame.ipynb                                             0.246702
# Untitled9.ipynb                                                    0.110236
# How to identify working directory.ipynb                            0.090644
# Pandas Package.ipynb                                               0.127724
#
#                                                     Exercise_Functions (Questions).ipynb  \
# Untitled7.ipynb                                                                 0.000000
# if-else statement.ipynb                                                         0.109553
# Launcher.ipynb                                                                  0.008253
# Untitled5.ipynb                                                                 0.000000
# Untitled1.ipynb                                                                 0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                                  0.002216
# Untitled3.ipynb                                                                 0.033658
# Untitled.ipynb                                                                  0.000000
# samira_chaunkaria_homework_3.ipynb                                              0.020586
# Untitled4.ipynb                                                                 0.000000
# Untitled6.ipynb                                                                 0.057304
# Robotic_OLS.ipynb                                                               0.025392
# NPV exercise.ipynb                                                              0.106328
# Pandas Problem Set - Solutions.ipynb                                            0.055880
# Capital Budgeting - Python examples (Questions)...                              0.089119
# Untitled2.ipynb                                                                 0.020586
# What are variables?.ipynb                                                       0.031167
# Practice Problem Set - Functions and IF stateme...                              0.181355
# Samira_Chaunkaria_extracredit.ipynb                                             0.052154
# Pandas Problem Set - Questions.ipynb                                            0.053481
# In class exercise 10-28.ipynb                                                   0.033712
# Untitled8.ipynb                                                                 0.000000
# If statements.ipynb                                                             0.094086
# HW3_Instruction-1.ipynb                                                         0.031276
# Exercise_Functions (Questions).ipynb                                            1.000000
# Extra Credit - Exercise of NUMPY (Duration Anal...                              0.070457
# Exercise_Functions (Solutions).ipynb                                            0.626465
# Pandas_DataFrame.ipynb                                                          0.007019
# Untitled9.ipynb                                                                 0.116367
# How to identify working directory.ipynb                                         0.014118
# Pandas Package.ipynb                                                            0.017771
#
#                                                     Extra Credit - Exercise of NUMPY (Duration Analysis).ipynb  \
# Untitled7.ipynb                                                                              0.000000
# if-else statement.ipynb                                                                      0.010731
# Launcher.ipynb                                                                               0.012153
# Untitled5.ipynb                                                                              0.000000
# Untitled1.ipynb                                                                              0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                                               0.013265
# Untitled3.ipynb                                                                              0.005846
# Untitled.ipynb                                                                               0.000000
# samira_chaunkaria_homework_3.ipynb                                                           0.047286
# Untitled4.ipynb                                                                              0.000000
# Untitled6.ipynb                                                                              0.342928
# Robotic_OLS.ipynb                                                                            0.017550
# NPV exercise.ipynb                                                                           0.109974
# Pandas Problem Set - Solutions.ipynb                                                         0.043912
# Capital Budgeting - Python examples (Questions)...                                           0.121867
# Untitled2.ipynb                                                                              0.047286
# What are variables?.ipynb                                                                    0.005680
# Practice Problem Set - Functions and IF stateme...                                           0.063059
# Samira_Chaunkaria_extracredit.ipynb                                                          0.475266
# Pandas Problem Set - Questions.ipynb                                                         0.065508
# In class exercise 10-28.ipynb                                                                0.018350
# Untitled8.ipynb                                                                              0.000000
# If statements.ipynb                                                                          0.010932
# HW3_Instruction-1.ipynb                                                                      0.135718
# Exercise_Functions (Questions).ipynb                                                         0.070457
# Extra Credit - Exercise of NUMPY (Duration Anal...                                           1.000000
# Exercise_Functions (Solutions).ipynb                                                         0.032906
# Pandas_DataFrame.ipynb                                                                       0.024513
# Untitled9.ipynb                                                                              0.023609
# How to identify working directory.ipynb                                                      0.073109
# Pandas Package.ipynb                                                                         0.010260
#
#                                                     Exercise_Functions (Solutions).ipynb  \
# Untitled7.ipynb                                                                 0.000000
# if-else statement.ipynb                                                         0.111685
# Launcher.ipynb                                                                  0.012971
# Untitled5.ipynb                                                                 0.000000
# Untitled1.ipynb                                                                 0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                                  0.002322
# Untitled3.ipynb                                                                 0.012269
# Untitled.ipynb                                                                  0.000000
# samira_chaunkaria_homework_3.ipynb                                              0.020745
# Untitled4.ipynb                                                                 0.000000
# Untitled6.ipynb                                                                 0.055173
# Robotic_OLS.ipynb                                                               0.015566
# NPV exercise.ipynb                                                              0.162007
# Pandas Problem Set - Solutions.ipynb                                            0.040353
# Capital Budgeting - Python examples (Questions)...                              0.060679
# Untitled2.ipynb                                                                 0.020745
# What are variables?.ipynb                                                       0.041146
# Practice Problem Set - Functions and IF stateme...                              0.113488
# Samira_Chaunkaria_extracredit.ipynb                                             0.049916
# Pandas Problem Set - Questions.ipynb                                            0.035211
# In class exercise 10-28.ipynb                                                   0.039736
# Untitled8.ipynb                                                                 0.000000
# If statements.ipynb                                                             0.089043
# HW3_Instruction-1.ipynb                                                         0.019387
# Exercise_Functions (Questions).ipynb                                            0.626465
# Extra Credit - Exercise of NUMPY (Duration Anal...                              0.032906
# Exercise_Functions (Solutions).ipynb                                            1.000000
# Pandas_DataFrame.ipynb                                                          0.009495
# Untitled9.ipynb                                                                 0.084987
# How to identify working directory.ipynb                                         0.009540
# Pandas Package.ipynb                                                            0.017836
#
#                                                     Pandas_DataFrame.ipynb  \
# Untitled7.ipynb                                                   0.000000
# if-else statement.ipynb                                           0.008352
# Launcher.ipynb                                                    0.019334
# Untitled5.ipynb                                                   0.000000
# Untitled1.ipynb                                                   0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                    0.367474
# Untitled3.ipynb                                                   0.247210
# Untitled.ipynb                                                    0.000000
# samira_chaunkaria_homework_3.ipynb                                0.112724
# Untitled4.ipynb                                                   0.000000
# Untitled6.ipynb                                                   0.012927
# Robotic_OLS.ipynb                                                 0.125710
# NPV exercise.ipynb                                                0.030582
# Pandas Problem Set - Solutions.ipynb                              0.244145
# Capital Budgeting - Python examples (Questions)...                0.021004
# Untitled2.ipynb                                                   0.112724
# What are variables?.ipynb                                         0.018660
# Practice Problem Set - Functions and IF stateme...                0.016094
# Samira_Chaunkaria_extracredit.ipynb                               0.013071
# Pandas Problem Set - Questions.ipynb                              0.293084
# In class exercise 10-28.ipynb                                     0.395418
# Untitled8.ipynb                                                   0.000000
# If statements.ipynb                                               0.008724
# HW3_Instruction-1.ipynb                                           0.246702
# Exercise_Functions (Questions).ipynb                              0.007019
# Extra Credit - Exercise of NUMPY (Duration Anal...                0.024513
# Exercise_Functions (Solutions).ipynb                              0.009495
# Pandas_DataFrame.ipynb                                            1.000000
# Untitled9.ipynb                                                   0.057378
# How to identify working directory.ipynb                           0.016899
# Pandas Package.ipynb                                              0.104195
#
#                                                     Untitled9.ipynb  \
# Untitled7.ipynb                                            0.000000
# if-else statement.ipynb                                    0.000000
# Launcher.ipynb                                             0.058079
# Untitled5.ipynb                                            0.000000
# Untitled1.ipynb                                            0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb             0.037656
# Untitled3.ipynb                                            0.073675
# Untitled.ipynb                                             0.000000
# samira_chaunkaria_homework_3.ipynb                         0.035789
# Untitled4.ipynb                                            0.000000
# Untitled6.ipynb                                            0.036849
# Robotic_OLS.ipynb                                          0.037475
# NPV exercise.ipynb                                         0.066050
# Pandas Problem Set - Solutions.ipynb                       0.059439
# Capital Budgeting - Python examples (Questions)...         0.030495
# Untitled2.ipynb                                            0.035789
# What are variables?.ipynb                                  0.009319
# Practice Problem Set - Functions and IF stateme...         0.060425
# Samira_Chaunkaria_extracredit.ipynb                        0.036090
# Pandas Problem Set - Questions.ipynb                       0.042750
# In class exercise 10-28.ipynb                              0.057166
# Untitled8.ipynb                                            0.000000
# If statements.ipynb                                        0.012699
# HW3_Instruction-1.ipynb                                    0.110236
# Exercise_Functions (Questions).ipynb                       0.116367
# Extra Credit - Exercise of NUMPY (Duration Anal...         0.023609
# Exercise_Functions (Solutions).ipynb                       0.084987
# Pandas_DataFrame.ipynb                                     0.057378
# Untitled9.ipynb                                            1.000000
# How to identify working directory.ipynb                    0.043275
# Pandas Package.ipynb                                       0.047515
#
#                                                     How to identify working directory.ipynb  \
# Untitled7.ipynb                                                                    0.000000
# if-else statement.ipynb                                                            0.050610
# Launcher.ipynb                                                                     0.409998
# Untitled5.ipynb                                                                    0.000000
# Untitled1.ipynb                                                                    0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                                     0.005610
# Untitled3.ipynb                                                                    0.013697
# Untitled.ipynb                                                                     0.000000
# samira_chaunkaria_homework_3.ipynb                                                 0.031890
# Untitled4.ipynb                                                                    0.000000
# Untitled6.ipynb                                                                    0.010232
# Robotic_OLS.ipynb                                                                  0.021837
# NPV exercise.ipynb                                                                 0.004467
# Pandas Problem Set - Solutions.ipynb                                               0.007593
# Capital Budgeting - Python examples (Questions)...                                 0.008797
# Untitled2.ipynb                                                                    0.031890
# What are variables?.ipynb                                                          0.015739
# Practice Problem Set - Functions and IF stateme...                                 0.020052
# Samira_Chaunkaria_extracredit.ipynb                                                0.015741
# Pandas Problem Set - Questions.ipynb                                               0.003361
# In class exercise 10-28.ipynb                                                      0.011091
# Untitled8.ipynb                                                                    0.000000
# If statements.ipynb                                                                0.045756
# HW3_Instruction-1.ipynb                                                            0.090644
# Exercise_Functions (Questions).ipynb                                               0.014118
# Extra Credit - Exercise of NUMPY (Duration Anal...                                 0.073109
# Exercise_Functions (Solutions).ipynb                                               0.009540
# Pandas_DataFrame.ipynb                                                             0.016899
# Untitled9.ipynb                                                                    0.043275
# How to identify working directory.ipynb                                            1.000000
# Pandas Package.ipynb                                                               0.009354
#
#                                                     Pandas Package.ipynb
# Untitled7.ipynb                                                 0.000000
# if-else statement.ipynb                                         0.003414
# Launcher.ipynb                                                  0.020472
# Untitled5.ipynb                                                 0.000000
# Untitled1.ipynb                                                 0.000000
# Intro to Pandas - In class demo (Oct 29).ipynb                  0.036846
# Untitled3.ipynb                                                 0.281073
# Untitled.ipynb                                                  0.000000
# samira_chaunkaria_homework_3.ipynb                              0.089586
# Untitled4.ipynb                                                 0.000000
# Untitled6.ipynb                                                 0.025964
# Robotic_OLS.ipynb                                               0.076379
# NPV exercise.ipynb                                              0.014538
# Pandas Problem Set - Solutions.ipynb                            0.252674
# Capital Budgeting - Python examples (Questions)...              0.037913
# Untitled2.ipynb                                                 0.089586
# What are variables?.ipynb                                       0.015421
# Practice Problem Set - Functions and IF stateme...              0.006189
# Samira_Chaunkaria_extracredit.ipynb                             0.025517
# Pandas Problem Set - Questions.ipynb                            0.181316
# In class exercise 10-28.ipynb                                   0.270787
# Untitled8.ipynb                                                 0.000000
# If statements.ipynb                                             0.004562
# HW3_Instruction-1.ipynb                                         0.127724
# Exercise_Functions (Questions).ipynb                            0.017771
# Extra Credit - Exercise of NUMPY (Duration Anal...              0.010260
# Exercise_Functions (Solutions).ipynb                            0.017836
# Pandas_DataFrame.ipynb                                          0.104195
# Untitled9.ipynb                                                 0.047515
# How to identify working directory.ipynb                         0.009354
# Pandas Package.ipynb                                            1.000000
#
# [31 rows x 31 columns]
#
# Highly Similar File Pairs (Threshold > 0.8):
# samira_chaunkaria_homework_3.ipynb and Untitled2.ipynb: Similarity = 1.00
# Untitled6.ipynb and Samira_Chaunkaria_extracredit.ipynb: Similarity = 0.89
# Pandas Problem Set - Solutions.ipynb and Pandas Problem Set - Questions.ipynb: Similarity = 0.92
